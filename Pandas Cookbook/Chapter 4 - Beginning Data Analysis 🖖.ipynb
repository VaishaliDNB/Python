# %% [markdown]
# # Day 12 - May 3, 2020

# %%
import pandas as pd
import numpy as np

college = pd.read_csv("D:\Learning Data Science\Python - Pandas\Pandas cookbook\Pandas-Cookbook-master\data\college.csv")

# %%
college.sample(random_state=42)
# Out:
#                     INSTNM         CITY STABBR  HBCU  MENONLY  WOMENONLY  \
# 3649  Career Point College  San Antonio     TX   0.0      0.0        0.0
#
#       RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  UGDS_NRA  \
# 3649         0       NaN       NaN           0.0  ...        0.0       0.0
#
#       UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 3649        0.0       0.0         1   0.9172    0.9172    0.697
#
#       MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 3649            20700               14977
#
# [1 rows x 27 columns]

# %%
college.shape
# Out:
# (7535, 27)

# %%
college.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7535 entries, 0 to 7534
# Data columns (total 27 columns):
# INSTNM                7535 non-null object
# CITY                  7535 non-null object
# STABBR                7535 non-null object
# HBCU                  7164 non-null float64
# MENONLY               7164 non-null float64
# WOMENONLY             7164 non-null float64
# RELAFFIL              7535 non-null int64
# SATVRMID              1185 non-null float64
# SATMTMID              1196 non-null float64
# DISTANCEONLY          7164 non-null float64
# UGDS                  6874 non-null float64
# UGDS_WHITE            6874 non-null float64
# UGDS_BLACK            6874 non-null float64
# UGDS_HISP             6874 non-null float64
# UGDS_ASIAN            6874 non-null float64
# UGDS_AIAN             6874 non-null float64
# UGDS_NHPI             6874 non-null float64
# UGDS_2MOR             6874 non-null float64
# UGDS_NRA              6874 non-null float64
# ...

# %%
# summary statistice for numberical columns only

college.describe(include=[np.number]).T
# Out:
#                count         mean          std    min         25%        50%  \
# HBCU          7164.0     0.014238     0.118478    0.0    0.000000    0.00000
# MENONLY       7164.0     0.009213     0.095546    0.0    0.000000    0.00000
# WOMENONLY     7164.0     0.005304     0.072642    0.0    0.000000    0.00000
# RELAFFIL      7535.0     0.190975     0.393096    0.0    0.000000    0.00000
# SATVRMID      1185.0   522.819409    68.578862  290.0  475.000000  510.00000
# SATMTMID      1196.0   530.765050    73.469767  310.0  482.000000  520.00000
# DISTANCEONLY  7164.0     0.005583     0.074519    0.0    0.000000    0.00000
# UGDS          6874.0  2356.837940  5474.275871    0.0  117.000000  412.50000
# UGDS_WHITE    6874.0     0.510207     0.286958    0.0    0.267500    0.55570
# UGDS_BLACK    6874.0     0.189997     0.224587    0.0    0.036125    0.10005
# UGDS_HISP     6874.0     0.161635     0.221854    0.0    0.027600    0.07140
# ...

# %%
# summary statistics for the object columns

college.describe(include=[np.object]).T
# Out:
#                    count unique                                  top  freq
# INSTNM              7535   7535  Du Bois Business College-Huntingdon     1
# CITY                7535   2514                             New York    87
# STABBR              7535     59                                   CA   773
# MD_EARN_WNE_P10     6413    598                    PrivacySuppressed   822
# GRAD_DEBT_MDN_SUPP  7503   2038                    PrivacySuppressed  1510

# %%
college.describe(include=[np.number], percentiles=[0.01, 0.05, 0.1, 0.25, 0.5, 0.75, 0.9, 0.95, 0.99]).T
# Out:
#                count         mean          std    min          1%          5%  \
# HBCU          7164.0     0.014238     0.118478    0.0    0.000000    0.000000
# MENONLY       7164.0     0.009213     0.095546    0.0    0.000000    0.000000
# WOMENONLY     7164.0     0.005304     0.072642    0.0    0.000000    0.000000
# RELAFFIL      7535.0     0.190975     0.393096    0.0    0.000000    0.000000
# SATVRMID      1185.0   522.819409    68.578862  290.0  390.000000  430.000000
# SATMTMID      1196.0   530.765050    73.469767  310.0  395.000000  430.000000
# DISTANCEONLY  7164.0     0.005583     0.074519    0.0    0.000000    0.000000
# UGDS          6874.0  2356.837940  5474.275871    0.0   14.000000   31.650000
# UGDS_WHITE    6874.0     0.510207     0.286958    0.0    0.000000    0.013265
# UGDS_BLACK    6874.0     0.189997     0.224587    0.0    0.000000    0.000000
# UGDS_HISP     6874.0     0.161635     0.221854    0.0    0.000000    0.000000
# ...

# %%
# College data dictionary

pd.read_csv("D:\Learning Data Science\Python - Pandas\Pandas cookbook\Pandas-Cookbook-master\data\college_data_dictionary.csv")
# Out:
#            column_name                                        description
# 0               INSTNM                                   Institution Name
# 1                 CITY                                      City Location
# 2               STABBR                                 State Abbreviation
# 3                 HBCU           Historically Black College or University
# 4              MENONLY                                       0/1 Men Only
# 5            WOMENONLY                                     0/1 Women only
# 6             RELAFFIL                          0/1 Religious Affiliation
# 7             SATVRMID                                  SAT Verbal Median
# 8             SATMTMID                                    SAT Math Median
# 9         DISTANCEONLY                            Distance Education Only
# 10                UGDS                           Undergraduate Enrollment
# 11          UGDS_WHITE                            Percent Undergrad White
# ...

# %% [markdown]
# ### Changing datatype of a column to reduce memory usage

# %%
different_cols = ["RELAFFIL","SATMTMID","CURROPER","INSTNM","STABBR",]

col2 = college.loc[:,different_cols]

col2
# Out:
#       RELAFFIL  SATMTMID  CURROPER  \
# 0            0     420.0         1
# 1            0     565.0         1
# 2            1       NaN         1
# 3            0     590.0         1
# 4            0     430.0         1
# ...        ...       ...       ...
# 7530         1       NaN         1
# 7531         1       NaN         1
# 7532         1       NaN         1
# 7533         1       NaN         1
# 7534         1       NaN         1
#
#                                                  INSTNM STABBR
# 0                              Alabama A & M University     AL
# 1                   University of Alabama at Birmingham     AL
# 2                                    Amridge University     AL
# 3                   University of Alabama in Huntsville     AL
# 4                              Alabama State University     AL
# ...                                                 ...    ...
# 7530         SAE Institute of Technology  San Francisco     CA
# ...

# %%
col2.dtypes
# Out:
# RELAFFIL      int64
# SATMTMID    float64
# CURROPER      int64
# INSTNM       object
# STABBR       object
# dtype: object

# %%
orig_mem = col2.memory_usage(deep=True) # deep = True is needed for the correct data size of the object columns
orig_mem
# Out:
# Index          128
# RELAFFIL     60280
# SATMTMID     60280
# CURROPER     60280
# INSTNM      660240
# STABBR      444565
# dtype: int64

# %%
col2.select_dtypes(include=["number"]).nunique()
# Out:
# RELAFFIL      2
# SATMTMID    167
# CURROPER      2
# dtype: int64

# %%
# converting RELAFFIL AND CURROPER, both containing only 0 and 1, to an 8 bit integer

col2["RELAFFIL"] = col2["RELAFFIL"].astype(np.int8)
col2["CURROPER"] = col2["CURROPER"].astype(np.int8)

# %%
col2.dtypes
# Out:
# RELAFFIL       int8
# SATMTMID    float64
# CURROPER       int8
# INSTNM       object
# STABBR       object
# dtype: object

# %%
col2.memory_usage(deep=True)
# Out:
# Index          128
# RELAFFIL      7535
# SATMTMID     60280
# CURROPER      7535
# INSTNM      660240
# STABBR      444565
# dtype: int64

# %%
col2.select_dtypes(include=["object"]).nunique()
# Out:
# INSTNM    7535
# STABBR      59
# dtype: int64

# %%
# converting STABBR, containing 59 values, to a categorical type

col2["STABBR"] = col2["STABBR"].astype("category")

# %%
col2.dtypes
# Out:
# RELAFFIL        int8
# SATMTMID     float64
# CURROPER        int8
# INSTNM        object
# STABBR      category
# dtype: object

# %%
new_mem = col2.memory_usage(deep=True)
new_mem
# Out:
# Index          128
# RELAFFIL      7535
# SATMTMID     60280
# CURROPER      7535
# INSTNM      660699
# STABBR       13576
# dtype: int64

# %%
new_mem/orig_mem
# Out:
# Index       1.000000
# RELAFFIL    0.125000
# SATMTMID    1.000000
# CURROPER    0.125000
# INSTNM      1.000695
# STABBR      0.030538
# dtype: float64

# %%
college.dtypes
# Out:
# INSTNM                 object
# CITY                   object
# STABBR                 object
# HBCU                  float64
# MENONLY               float64
# WOMENONLY             float64
# RELAFFIL                int64
# SATVRMID              float64
# SATMTMID              float64
# DISTANCEONLY          float64
# UGDS                  float64
# UGDS_WHITE            float64
# UGDS_BLACK            float64
# UGDS_HISP             float64
# UGDS_ASIAN            float64
# UGDS_AIAN             float64
# UGDS_NHPI             float64
# UGDS_2MOR             float64
# UGDS_NRA              float64
# UGDS_UNKN             float64
# PPTUG_EF              float64
# CURROPER                int64
# PCTPELL               float64
# PCTFLOAN              float64
# UG25ABV               float64
# MD_EARN_WNE_P10        object
# GRAD_DEBT_MDN_SUPP     object
# dtype: object

# %%
college.memory_usage(deep = True)
# Out:
# Index                    128
# INSTNM                660699
# CITY                  496019
# STABBR                444565
# HBCU                   60280
# MENONLY                60280
# WOMENONLY              60280
# RELAFFIL               60280
# SATVRMID               60280
# SATMTMID               60280
# DISTANCEONLY           60280
# UGDS                   60280
# UGDS_WHITE             60280
# UGDS_BLACK             60280
# UGDS_HISP              60280
# UGDS_ASIAN             60280
# UGDS_AIAN              60280
# UGDS_NHPI              60280
# UGDS_2MOR              60280
# UGDS_NRA               60280
# UGDS_UNKN              60280
# PPTUG_EF               60280
# CURROPER               60280
# PCTPELL                60280
# PCTFLOAN               60280
# UG25ABV                60280
# MD_EARN_WNE_P10       443397
# GRAD_DEBT_MDN_SUPP    484160
# dtype: int64

# %%
college.loc[0, "CURROPER"] #CURROPER memory usage is 60280
# Out:
# 1

# %%
college.loc[0, "CURROPER"] = 10000000

college.memory_usage(deep = True) # no change in CURROPER memory size, since it is already big enough
# Out:
# Index                    128
# INSTNM                660699
# CITY                  496019
# STABBR                444565
# HBCU                   60280
# MENONLY                60280
# WOMENONLY              60280
# RELAFFIL               60280
# SATVRMID               60280
# SATMTMID               60280
# DISTANCEONLY           60280
# UGDS                   60280
# UGDS_WHITE             60280
# UGDS_BLACK             60280
# UGDS_HISP              60280
# UGDS_ASIAN             60280
# UGDS_AIAN              60280
# UGDS_NHPI              60280
# UGDS_2MOR              60280
# UGDS_NRA               60280
# UGDS_UNKN              60280
# PPTUG_EF               60280
# CURROPER               60280
# PCTPELL                60280
# PCTFLOAN               60280
# UG25ABV                60280
# MD_EARN_WNE_P10       443397
# GRAD_DEBT_MDN_SUPP    484160
# dtype: int64

# %%
college.loc[0, "INSTNM"]
# Out:
# 'Alabama A & M University'

# %%
college.loc[0, "INSTNM"] = college.loc[0, "INSTNM"] +"a"

college.memory_usage(deep = True) # memory usage changed for the object type INSTNM with change in value
# Out:
# Index                    128
# INSTNM                660752
# CITY                  496019
# STABBR                444565
# HBCU                   60280
# MENONLY                60280
# WOMENONLY              60280
# RELAFFIL               60280
# SATVRMID               60280
# SATMTMID               60280
# DISTANCEONLY           60280
# UGDS                   60280
# UGDS_WHITE             60280
# UGDS_BLACK             60280
# UGDS_HISP              60280
# UGDS_ASIAN             60280
# UGDS_AIAN              60280
# UGDS_NHPI              60280
# UGDS_2MOR              60280
# UGDS_NRA               60280
# UGDS_UNKN              60280
# PPTUG_EF               60280
# CURROPER               60280
# PCTPELL                60280
# PCTFLOAN               60280
# UG25ABV                60280
# MD_EARN_WNE_P10       443397
# GRAD_DEBT_MDN_SUPP    484160
# dtype: int64

# %%
# in the number types, only the float64 or int64 can accomodate nan values, 
# MENONLY cannot be converted to 8 bit since it has na values

college["MENONLY"].hasnans
# Out:
# True

# %%
college["MENONLY"].memory_usage()
# Out:
# 60408

# %%
college["MENONLY"].dtype
# Out:
# dtype('float64')

# %%
college["MENONLY"].describe()
# Out:
# count    7164.000000
# mean        0.009213
# std         0.095546
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: MENONLY, dtype: float64

# %%
# college["MENONLY"].astype(np.int8)    # error - "ValueError: Cannot convert non-finite values (NA or inf) to integer"

# %%
college.describe(include=['int64', 'float64']).shape
# Out:
# (8, 22)

# %%
college.describe(include=[np.int64, np.float64]).shape
# Out:
# (8, 22)

# %% [markdown]
# ##### why is the below missing relaffil and curroper??

# %%
college.describe(include=['int', 'float']).shape
# Out:
# (8, 20)

# %%
college.describe(include=['number']).shape
# Out:
# (8, 22)

# %%
# converting multiple columns' types together

college.assign(
    MENONLY = college["MENONLY"].astype("float16"),
    REAFFIL = college["RELAFFIL"].astype("int8")
)
# Out:
#                                                  INSTNM              CITY  \
# 0                             Alabama A & M Universitya            Normal
# 1                   University of Alabama at Birmingham        Birmingham
# 2                                    Amridge University        Montgomery
# 3                   University of Alabama in Huntsville        Huntsville
# 4                              Alabama State University        Montgomery
# ...                                                 ...               ...
# 7530         SAE Institute of Technology  San Francisco        Emeryville
# 7531                  Rasmussen College - Overland Park     Overland Park
# 7532  National Personal Training Institute of Cleveland  Highland Heights
# 7533  Bay Area Medical Academy - San Jose Satellite ...          San Jose
# 7534            Excel Learning Center-San Antonio South       San Antonio
#
#      STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# ...

# %%
# memory difference between RangeIndex and Int64Index

college.index.memory_usage()
# Out:
# 128

# %%
college.index = pd.Int64Index(college.index)

# %%
college.index.memory_usage()
# Out:
# 60280

# %% [markdown]
# # Day 13 - May 4, 2020

# %% [markdown]
# ### Selecting the smallest of the largest

# %%
# nlargest and nsmallest

movie = pd.read_csv('D:\Learning Data Science\Python - Pandas\Pandas cookbook\Pandas-Cookbook-master\data\movie.csv')

# %%
movie.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
movie2 = movie[['movie_title', 'imdb_score', 'budget']]

# %%
movie2.head()
# Out:
#                                   movie_title  imdb_score       budget
# 0                                      Avatar         7.9  237000000.0
# 1    Pirates of the Caribbean: At World's End         7.1  300000000.0
# 2                                     Spectre         6.8  245000000.0
# 3                       The Dark Knight Rises         8.5  250000000.0
# 4  Star Wars: Episode VII - The Force Awakens         7.1          NaN

# %%
movie2.nlargest(100, 'imdb_score')
# Out:
#                    movie_title  imdb_score      budget
# 2725          Towering Inferno         9.5         NaN
# 1920  The Shawshank Redemption         9.3  25000000.0
# 3402             The Godfather         9.2   6000000.0
# 2779                   Dekalog         9.1         NaN
# 4312      Kickboxer: Vengeance         9.1  17000000.0
# ...                        ...         ...         ...
# 4023                    Oldboy         8.4   3000000.0
# 4163     To Kill a Mockingbird         8.4   2000000.0
# 4395            Reservoir Dogs         8.4   1200000.0
# 4550              A Separation         8.4    500000.0
# 4636      The Other Dream Team         8.4    500000.0
#
# [100 rows x 3 columns]

# %%
movie2.nlargest(100, 'imdb_score').nsmallest(5, 'budget')
# Out:
#                movie_title  imdb_score    budget
# 4804        Butterfly Girl         8.7  180000.0
# 4801    Children of Heaven         8.5  180000.0
# 4706          12 Angry Men         8.9  350000.0
# 4550          A Separation         8.4  500000.0
# 4636  The Other Dream Team         8.4  500000.0

# %% [markdown]
# ### Selecting the largest of each group by sorting

# %%
movie.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
movie[['movie_title','title_year','imdb_score']]
# Out:
#                                      movie_title  title_year  imdb_score
# 0                                         Avatar      2009.0         7.9
# 1       Pirates of the Caribbean: At World's End      2007.0         7.1
# 2                                        Spectre      2015.0         6.8
# 3                          The Dark Knight Rises      2012.0         8.5
# 4     Star Wars: Episode VII - The Force Awakens         NaN         7.1
# ...                                          ...         ...         ...
# 4911                     Signed Sealed Delivered      2013.0         7.7
# 4912                               The Following         NaN         7.5
# 4913                        A Plague So Pleasant      2013.0         6.3
# 4914                            Shanghai Calling      2012.0         6.3
# 4915                           My Date with Drew      2004.0         6.6
#
# [4916 rows x 3 columns]

# %%
movie[['movie_title','title_year','imdb_score']].sort_values('title_year', ascending = True)
# Out:
#                                            movie_title  title_year  imdb_score
# 4695  Intolerance: Love's Struggle Throughout the Ages      1916.0         8.0
# 4833                    Over the Hill to the Poorhouse      1920.0         4.8
# 4767                                    The Big Parade      1925.0         8.3
# 2694                                        Metropolis      1927.0         8.3
# 4697                               The Broadway Melody      1929.0         6.3
# ...                                                ...         ...         ...
# 4683                                            Heroes         NaN         7.7
# 4688                                       Home Movies         NaN         8.2
# 4704                                        Revolution         NaN         6.7
# 4752                                      Happy Valley         NaN         8.5
# 4912                                     The Following         NaN         7.5
#
# [4916 rows x 3 columns]

# %%
movie[['movie_title','title_year','imdb_score']].sort_values(['title_year', 'imdb_score'], ascending = False)
# Out:
#                       movie_title  title_year  imdb_score
# 4312         Kickboxer: Vengeance      2016.0         9.1
# 4277  A Beginner's Guide to Snuff      2016.0         8.7
# 3798                      Airlift      2016.0         8.5
# 27     Captain America: Civil War      2016.0         8.2
# 98            Godzilla Resurgence      2016.0         8.2
# ...                           ...         ...         ...
# 1391                    Rush Hour         NaN         5.8
# 4031                     Creature         NaN         5.0
# 2165              Meet the Browns         NaN         3.5
# 3246   The Bold and the Beautiful         NaN         3.5
# 2119                 The Bachelor         NaN         2.9
#
# [4916 rows x 3 columns]

# %%
movie[['movie_title','title_year','imdb_score']].sort_values(['title_year', 'imdb_score'], ascending = False).drop_duplicates(subset = 'title_year')
# Out:
#                                            movie_title  title_year  imdb_score
# 4312                              Kickboxer: Vengeance      2016.0         9.1
# 3745                                   Running Forever      2015.0         8.6
# 4369                            Queen of the Mountains      2014.0         8.7
# 3935           Batman: The Dark Knight Returns, Part 2      2013.0         8.4
# 3                                The Dark Knight Rises      2012.0         8.5
# ...                                                ...         ...         ...
# 2694                                        Metropolis      1927.0         8.3
# 4767                                    The Big Parade      1925.0         8.3
# 4833                    Over the Hill to the Poorhouse      1920.0         4.8
# 4695  Intolerance: Love's Struggle Throughout the Ages      1916.0         8.0
# 2725                                  Towering Inferno         NaN         9.5
#
# [92 rows x 3 columns]

# %%
# using groupby for the same

(
movie[['movie_title', 'title_year', 'imdb_score']]
.groupby("title_year", as_index = False)
.apply(lambda df: df.sort_values('imdb_score', ascending = False).head(1))
.droplevel(0)
.sort_values('title_year', ascending = False)
)
# Out:
#                                            movie_title  title_year  imdb_score
# 4312                              Kickboxer: Vengeance      2016.0         9.1
# 3745                                   Running Forever      2015.0         8.6
# 4369                            Queen of the Mountains      2014.0         8.7
# 3935           Batman: The Dark Knight Returns, Part 2      2013.0         8.4
# 3                                The Dark Knight Rises      2012.0         8.5
# ...                                                ...         ...         ...
# 4555                                     Pandora's Box      1929.0         8.0
# 2694                                        Metropolis      1927.0         8.3
# 4767                                    The Big Parade      1925.0         8.3
# 4833                    Over the Hill to the Poorhouse      1920.0         4.8
# 4695  Intolerance: Love's Struggle Throughout the Ages      1916.0         8.0
#
# [91 rows x 3 columns]

# %%
# sorting one column in ascending order and the other in descending order

(
movie[['movie_title', 'title_year', 'content_rating', 'budget']]
.sort_values(['title_year', 'content_rating', 'budget'], ascending = [False, False, True])
.drop_duplicates(subset = ['title_year', 'content_rating'])
)
# Out:
#                          movie_title  title_year content_rating      budget
# 4026                       Compadres      2016.0              R   3000000.0
# 4658             Fight to the Finish      2016.0          PG-13    150000.0
# 4661                      Rodeo Girl      2016.0             PG    500000.0
# 3252                     The Wailing      2016.0      Not Rated         NaN
# 4659  Alleluia! The Devil's Carnival      2016.0            NaN    500000.0
# ...                              ...         ...            ...         ...
# 2558                      Lilyhammer         NaN          TV-MA  34000000.0
# 807       Sabrina, the Teenage Witch         NaN           TV-G   3000000.0
# 848                    Stargate SG-1         NaN          TV-14   1400000.0
# 2436                          Carlos         NaN      Not Rated         NaN
# 2119                    The Bachelor         NaN            NaN   3000000.0
#
# [359 rows x 4 columns]

# %% [markdown]
# # Day 14 - May 5, 2020

# %% [markdown]
# ### Replicating nlargest with sort_values

# %%
# Selecting the smallest of the largest

(
movie[['movie_title', 'imdb_score', 'budget']]
.nlargest(100, 'imdb_score')
.nsmallest(5, 'budget')
)
# Out:
#                movie_title  imdb_score    budget
# 4804        Butterfly Girl         8.7  180000.0
# 4801    Children of Heaven         8.5  180000.0
# 4706          12 Angry Men         8.9  350000.0
# 4550          A Separation         8.4  500000.0
# 4636  The Other Dream Team         8.4  500000.0

# %%
# replicating the above using sort_values

(
movie[['movie_title', 'imdb_score', 'budget']]
.sort_values('imdb_score', ascending = False)
.head(100)
.sort_values('budget')
.head(5)
)
# Out:
#                     movie_title  imdb_score    budget
# 4815  A Charlie Brown Christmas         8.4  150000.0
# 4801         Children of Heaven         8.5  180000.0
# 4804             Butterfly Girl         8.7  180000.0
# 4706               12 Angry Men         8.9  350000.0
# 4636       The Other Dream Team         8.4  500000.0

# %% [markdown]
# ### Calculating a trailing stop order price

# %%
import datetime
import pandas_datareader.data as web
import requests_cache

session = requests_cache.CachedSession(cache_name = 'cache', backend = 'sqlite', expire_after = datetime.timedelta(days=90))

# getting the Tesla Motors (TSLA) stock price
tsla = web.DataReader('tsla', data_source='yahoo', start = '2017-1-1', session = session)

# %%
tsla.head(8)
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2017-01-03  220.330002  210.960007  214.860001  216.990005   5923300
# 2017-01-04  228.000000  214.309998  214.750000  226.990005  11213500
# 2017-01-05  227.479996  221.949997  226.419998  226.750000   5911700
# 2017-01-06  230.309998  225.449997  226.929993  229.009995   5527900
# 2017-01-09  231.919998  228.000000  228.970001  231.279999   3979500
# 2017-01-10  232.000000  226.889999  232.000000  229.869995   3660000
# 2017-01-11  229.979996  226.679993  229.070007  229.729996   3650800
# 2017-01-12  230.699997  225.580002  229.059998  229.589996   3790200
#
#              Adj Close
# Date
# 2017-01-03  216.990005
# 2017-01-04  226.990005
# 2017-01-05  226.750000
# 2017-01-06  229.009995
# 2017-01-09  231.279999
# 2017-01-10  229.869995
# 2017-01-11  229.729996
# 2017-01-12  229.589996

# %%
tsla
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2017-01-03  220.330002  210.960007  214.860001  216.990005   5923300
# 2017-01-04  228.000000  214.309998  214.750000  226.990005  11213500
# 2017-01-05  227.479996  221.949997  226.419998  226.750000   5911700
# 2017-01-06  230.309998  225.449997  226.929993  229.009995   5527900
# 2017-01-09  231.919998  228.000000  228.970001  231.279999   3979500
# ...                ...         ...         ...         ...       ...
# 2020-04-28  805.000000  756.690002  795.640015  769.119995  15222000
# 2020-04-29  803.200012  783.159973  790.169983  800.510010  16216000
# 2020-04-30  869.820007  763.500000  855.190002  781.880005  28471900
# 2020-05-01  772.770020  683.039978  755.000000  701.320007  32531800
# 2020-05-04  762.000000  698.000000  701.000000  761.190002  19159300
#
#              Adj Close
# Date
# 2017-01-03  216.990005
# 2017-01-04  226.990005
# 2017-01-05  226.750000
# 2017-01-06  229.009995
# ...

# %%
tsla_close = tsla["Close"]

# %%
tsla_cummax = tsla_close.cummax()
tsla_cummax.head()
# Out:
# Date
# 2017-01-03    216.990005
# 2017-01-04    226.990005
# 2017-01-05    226.990005
# 2017-01-06    229.009995
# 2017-01-09    231.279999
# Name: Close, dtype: float64

# %%
tsla_cummax.mul(0.9).head()
# Out:
# Date
# 2017-01-03    195.291005
# 2017-01-04    204.291005
# 2017-01-05    204.291005
# 2017-01-06    206.108995
# 2017-01-09    208.151999
# Name: Close, dtype: float64

# %%
# chaining all above together

tsla['Close'].cummax().mul(0.9).head()
# Out:
# Date
# 2017-01-03    195.291005
# 2017-01-04    204.291005
# 2017-01-05    204.291005
# 2017-01-06    206.108995
# 2017-01-09    208.151999
# Name: Close, dtype: float64

# %% [markdown]
# ### End of Chapter 4
